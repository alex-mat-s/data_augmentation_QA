# %%
import pandas as pd
from pathlib import Path

# %%
BASE_DIR = Path('EDA.ipynb').resolve().parent.parent
DATA_DIR = BASE_DIR.joinpath('data')
FILE_NAME = "MedQuAD_Russian.csv"

FILE = DATA_DIR.joinpath(FILE_NAME)

# %%
data = pd.read_csv(FILE, sep=",")

print(data.info())
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1453 entries, 0 to 1452
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0.1        1453 non-null   int64
#  1   Unnamed: 0          1453 non-null   int64
#  2   Question            1453 non-null   object
#  3   URL                 1453 non-null   object
#  4   Answer              1453 non-null   object
#  5   context             1453 non-null   object
#  6   Answer_Start_Index  1453 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 79.6+ KB
# None
#    Unnamed: 0.1  Unnamed: 0  \
# 0             2           2
# 1             3           3
# 2             4           4
# 3             7          10
# 4             8          11
# 5            12          18
# 6            25          32
# 7            27          39
# 8            28          42
# 9            31          46
#
#                                             Question  \
# 0                Вопрос: Что вызывает синдром Нунан?
# 1          Вопрос: Каковы осложнения синдрома Нунан?
# 2           Вопрос: Как предотвратить синдром Нунан?
# 3                   Вопрос: Что такое синдром Нунан?
# 4                Вопрос: Что вызывает синдром Нунан?
# 5  Вопрос: Что такое целиакия – вопросы питания? ...
# 6  Вопрос: Что такое целиакия? (Также называется:...
# 7  Вопрос: Что такое чувствительность к глютену? ...
# 8  Вопрос: Что такое целиакия – вопросы питания? ...
# 9  Вопрос: Есть ли у вас информация о Комплексной...
#
#                                                  URL  \
# 0  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 1  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 2  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 3  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 4  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 5  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 6  https://www.nlm.nih.gov/medlineplus/celiacdise...
# 7  https://www.nlm.nih.gov/medlineplus/glutensens...
# 8  https://www.nlm.nih.gov/medlineplus/ency/artic...
# 9  https://www.nlm.nih.gov/medlineplus/ency/artic...
#
#                                               Answer  \
# 0  Синдром Нунан связан с дефектами нескольких ге...
# 1  - Накопление жидкости в тканях организма (лимф...
# 2  Пары с семейным анамнезом синдрома Нунан, возм...
# 3  Синдром Нунан – это заболевание, которое может...
# 4  Синдром Нунан связан с дефектами нескольких ге...
# 5  Целиакия – это иммунное заболевание, передающе...
# 6  Целиакия — это иммунное заболевание, при котор...
# 7  Глютен – это белок, содержащийся в пшенице, рж...
# 8  Целиакия – это иммунное заболевание, передающе...
# 9  Резюме: Комплексная метаболическая панель пред...
#
#                                              context  Answer_Start_Index
# 0  Синдром Нунан — это заболевание, присутствующе...                   0
# 1  Синдром Нунан — это заболевание, присутствующе...                  -1
# 2  Синдром Нунан — это заболевание, присутствующе...                2184
# 3  Синдром Нунан — это заболевание, присутствующе...                   0
# 4  Синдром Нунан — это заболевание, присутствующе...                   0
# 5  Целиакия — это иммунное заболевание, передающе...                   0
# 6  На этой странице Основные сведения Начните зде...                  -1
# 7  Резюме: Глютен — это белок, содержащийся в пше...                   8
# 8  Целиакия — это иммунное заболевание, передающе...                   0
# 9  Комплексная метаболическая панель представляет...                  -1

# %%
data.iloc[1]["context"]
# Out:
# 'Синдром Нунан — это заболевание, присутствующее с рождения (врожденное), которое вызывает аномальное развитие многих частей тела. В некоторых случаях он передается по наследству (по наследству). Причины синдрома Нунан связаны с дефектами нескольких генов. В целом, некоторые белки, участвующие в росте и развитии, становятся сверхактивными в результате этих генных изменений. Синдром Нунан является аутосомно-доминантным заболеванием. Это означает, что только один родитель должен передать неработающий ген, чтобы ребенок заболел синдромом. Однако некоторые случаи могут не передаваться по наследству. Симптомы Симптомы включают в себя: Задержку полового созревания. Раскосые или широко посаженные глаза. Потеря слуха (варьируется). Низко посаженные уши или уши неправильной формы. Легкая умственная отсталость (только примерно в 25% случаев). ростМаленький половой членНеопущенные яичкиНеобычная форма груди (чаще всего впалая грудь, называемая воронкообразной грудной клеткой)Перепончатая и короткая шея Обследования и тесты Медицинский работник проведет медицинский осмотр. Это может указывать на признаки проблем с сердцем, которые были у ребенка с рождения. Они могут включать стеноз легочной артерии и дефект межпредсердной перегородки. Обследования зависят от симптомов, но могут включать в себя: подсчет тромбоцитов; анализ фактора свертывания крови; ЭКГ, рентген грудной клетки или эхокардиограмму; тесты на слух; уровни гормона роста; УЗИ почек. Генетическое тестирование может помочь диагностировать этот синдром. Лечение Специфического метода не существует. уход. Ваш врач предложит лечение для облегчения или контроля симптомов. Гормон роста успешно используется для лечения низкого роста у некоторых людей с синдромом Нунан. Группы поддержки. Дополнительную информацию и поддержку для людей с синдромом Нунан и их семей можно найти на сайте www.teamnoonan.org. Возможные осложнения Осложнения могут включать: Аномальное кровотечение или образование синяков Накопление жидкости в тканях тела (лимфедема, кистозная гигрома) Задержка развития у младенцев Лейкемия и другие виды рака Низкая самооценка Бесплодие у мужчин, если оба яичка неопустились Проблемы со структурой сердца Низкий рост Социальные проблемы, связанные с физическими симптомами Когда обращаться к врачу Медицинский работник Это состояние можно обнаружить во время раннего осмотра ребенка. Для диагностики синдрома Нунан часто необходим генетик. Профилактика Пары с семейным анамнезом синдрома Нунан, возможно, захотят рассмотреть возможность генетического консультирования, прежде чем заводить детей. Изображения Pectus excavatum'

# %%
data.iloc[1]["Answer"]
# Out:
# '- Накопление жидкости в тканях организма (лимфедема, кистозная гигрома) - Задержка развития у младенцев - Низкая самооценка - Бесплодие у мужчин, если оба яичка неопущены - Проблемы со структурой сердца - Низкий рост - Социальные проблемы из-за физические симптомы)'

# %%
data["Answer_Start_Index"].value_counts()
# Out:
# Answer_Start_Index
# -1       450
#  0       360
#  12       65
#  20       55
#  8         8
#         ...
#  1151      1
#  617       1
#  159       1
#  3129      1
#  1346      1
# Name: count, Length: 391, dtype: int64
